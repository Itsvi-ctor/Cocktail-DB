# %% [markdown]
# <a href="https://colab.research.google.com/github/Itsvi-ctor/Cocktail-DB/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder_path_healthy = 'drive/My Drive/Healthy/'
file_name_healthy = "1.wav"

# %%
folder_path_unhealthy = 'drive/My Drive/Unhealthy/'
file_name_unhealthy = "1.wav"

# %%
f_path_healthy = folder_path_healthy + file_name_healthy
f_path_unhealthy = folder_path_unhealthy + file_name_unhealthy

# %%
def load_wav_16k_mono(filename):
    # Load encoded wav file
    file_contents = tf.io.read_file(filename)
    # Decode wav (tensors by channels)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    # Removes trailing axis
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    # Goes from 44100Hz to 16000hz - amplitude of the audio signal
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %%
# !pip uninstall tensorflow-io
# !pip install tensorflow-io==0.34.0  # Replace with a version that might be compatible
# Out:
# Found existing installation: tensorflow-io 0.34.0
# Uninstalling tensorflow-io-0.34.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/tensorflow_io-0.34.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow_io/*
# Proceed (Y/n)? Y
#   Successfully uninstalled tensorflow-io-0.34.0
# ...
#   Using cached tensorflow_io-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.8 MB)
# ...

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==2.13.0  # Replace with a version that might be compatible
# Out:
# Found existing installation: tensorflow 2.14.0
# Uninstalling tensorflow-2.14.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.14.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
# Proceed (Y/n)? Y
#   Successfully uninstalled tensorflow-2.14.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 66.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 40.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
# ...

# %%
wave = load_wav_16k_mono(f_path_healthy)
nwave = load_wav_16k_mono(f_path_unhealthy)

# %%
plt.plot(wave)
plt.plot(nwave)
plt.show()

# %%
POS = folder_path_healthy
NEG = folder_path_unhealthy

# %%
pos = tf.data.Dataset.list_files(POS+'*.wav')
neg = tf.data.Dataset.list_files(NEG+'*.wav')

# %% [markdown]
# Add Labels and Combine positive and negative samples

# %%
positives = tf.data.Dataset.zip((pos, tf.data.Dataset.from_tensor_slices(tf.ones(len(pos)))))
negatives = tf.data.Dataset.zip((neg, tf.data.Dataset.from_tensor_slices(tf.zeros(len(neg)))))
data = positives.concatenate(negatives)

# %%
data.shuffle(1000).as_numpy_iterator().next()
# Out:
# (b'drive/My Drive/Healthy/29.wav', 1.0)

# %%
lengths = []
for file in os.listdir(folder_path_healthy):
    tensor_wave = load_wav_16k_mono(os.path.join(folder_path_healthy, file))
    lengths.append(len(tensor_wave))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fdbb0f01120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [markdown]
# # Calculate, Min, Max and Mean

# %% [markdown]
# # Build preprocessing function to convert to spectrogram

# %%
def preprocess(folder_path_healthy, label):
    wav = load_wav_16k_mono(folder_path_healthy)
    wav = wav[:25719]
    zero_padding = tf.zeros([25719] - tf.shape(wav), dtype=tf.float32)
    wav = tf.concat([zero_padding, wav],0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram, label

# %%
wav = load_wav_16k_mono(f_path_healthy)
wav = wav[:25719]
zero_padding = tf.zeros([25719] - tf.shape(wav), dtype=tf.float32)
wav = tf.concat([zero_padding, wav],0)
wav
# Out:
# <tf.Tensor: shape=(25719,), dtype=float32, numpy=
# array([-3.9605407e-08,  5.7284616e-08, -4.4438686e-08, ...,
#        -4.4289753e-02, -4.4812597e-02, -4.5013487e-02], dtype=float32)>

# %%
spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
spectrogram = tf.abs(spectrogram)
spectrogram = tf.expand_dims(spectrogram, axis=2)
spectrogram
# Out:
# <tf.Tensor: shape=(794, 257, 1), dtype=float32, numpy=
# array([[[1.8214947e-01],
#         [2.5440079e-01],
#         [3.3495557e-01],
#         ...,
#         [6.8174113e-06],
#         [2.7344038e-06],
#         [2.7716160e-06]],
#
#        [[1.3225275e-01],
#         [6.8693332e-02],
#         [3.1061485e-01],
#         ...,
#         [7.5808734e-06],
#         [2.1055703e-06],
#         [4.7013164e-06]],
#
#        [[3.1738520e-01],
#         [3.8530326e-01],
#         [4.7882614e-01],
#         ...,
#         [8.7475710e-06],
#         [1.5833141e-06],
#         [4.3064356e-06]],
#
#        ...,
#
#        [[6.6324973e-01],
#         [1.9532193e+00],
#         [2.4328182e+00],
#         ...,
#         [2.0970672e-05],
#         [9.5100704e-06],
#         [7.1525574e-07]],
#
#        [[2.0912552e+00],
#         [2.6363292e+00],
#         [2.8059378e+00],
#         ...,
#         [2.3545872e-05],
#         [9.2069404e-06],
#         [9.5367432e-07]],
#
#        [[2.9799509e+00],
# ...

# %%
filepath, label = negatives.shuffle(buffer_size=10000).as_numpy_iterator().next()

# %%
spectrogram, label = preprocess(filepath, label)

# %%
plt.figure(figsize=(30,20))
plt.imshow(tf.transpose(spectrogram)[0])
plt.show()

# %%
data.as_numpy_iterator().next()
# Out:
# (b'drive/My Drive/Healthy/112.wav', 1.0)

# %%
data = data.map(preprocess)
data = data.cache()
data = data.shuffle(buffer_size=1000)
data = data.batch(16)
data = data.prefetch(8)
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.

# %%
len(data)*.7
# Out:
# 11.899999999999999

# %%
train = data.take(12)
test = data.skip(12).take(6)

# %%
samples, labels = train.as_numpy_iterator().next()

# %%
samples.shape
# Out:
# (16, 794, 257, 1)

# %% [markdown]
# # Build deep learning model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(794, 257,1)))
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('Adam', loss='BinaryCrossentropy', metrics=[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 792, 255, 16)      160
#
#  conv2d_3 (Conv2D)           (None, 790, 253, 16)      2320
#
#  flatten_1 (Flatten)         (None, 3197920)           0
#
#  dense_2 (Dense)             (None, 128)               409333888
#
#  dense_3 (Dense)             (None, 1)                 129
#
# ...
# Total params: 409336497 (1.52 GB)
# Trainable params: 409336497 (1.52 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# hist = model.fit(train, epochs=4, validation_data=test)
history = model.fit(train, epochs=4, validation_data=test)
# Out:
# Epoch 1/4
# 12/12 [==============================] - 134s 11s/step - loss: 7.3278 - recall: 0.7059 - precision: 0.8000 - val_loss: 2.6454 - val_recall: 0.7297 - val_precision: 0.9643
# Epoch 2/4
# 12/12 [==============================] - 129s 11s/step - loss: 1.4285 - recall: 0.8000 - precision: 0.9438 - val_loss: 0.6407 - val_recall: 0.9744 - val_precision: 0.8837
# Epoch 3/4
# 12/12 [==============================] - 132s 11s/step - loss: 0.2339 - recall: 0.9596 - precision: 0.9406 - val_loss: 0.0409 - val_recall: 0.9655 - val_precision: 0.9655
# Epoch 4/4
# 12/12 [==============================] - 131s 11s/step - loss: 0.1443 - recall: 0.9479 - precision: 0.9891 - val_loss: 0.1759 - val_recall: 0.9750 - val_precision: 0.9070

# %%
plt.title('Loss')
plt.plot(history.history['loss'], 'r')
plt.plot(history.history['val_loss'], 'b')
plt.show()

# %%
plt.title('Precision')
plt.plot(history.history['precision'], 'r')
plt.plot(history.history['val_precision'], 'b')
plt.show()

# %%
plt.title('Recall')
plt.plot(history.history['recall'], 'b')
plt.plot(history.history['val_recall'], 'r')
plt.show()

# %% [markdown]
# # Make a prediction on a single clip

# %%
X_test, y_test = test.as_numpy_iterator().next()

# %%
# Assuming X_test is assigned the actual testing data properly
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
yhat = [1 if prediction > 0.5 else 0 for prediction in yhat]

# %%
tf.math.reduce_sum(yhat)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=7>

# %%
tf.math.reduce_sum(y_test)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=7.0>
